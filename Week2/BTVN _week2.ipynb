# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from typing_extensions import dataclass_transform
import pandas as pd
URL = 'http://winterolympicsmedals.com/medals.csv'
DataFrame = pd.read_csv(URL)

# %% [markdown]
# Năm 1924 , huy chuong Vang, tp Chamonix

# %%
DataFrame[(DataFrame['Year']==1924)&(DataFrame['Medal']=='Gold')&(DataFrame['City']=='Chamonix')].head(100)

# %% [markdown]
# Năm 1924 , huy chuong bac, tp Chamonix

# %%
DataFrame[(DataFrame['Year']==1924)&(DataFrame['Medal']=='Silver')&(DataFrame['City']=='Chamonix')].head(100)

# %% [markdown]
# Năm 1924 , huy chuong dong, tp Chamonix

# %%
DataFrame[(DataFrame['Year']==1924)&(DataFrame['City']=='Chamonix')&(DataFrame['Medal']=='Bronze')].head(100)

# %%
DataFrame[(DataFrame['City']=='Chamonix')]

# %%
DataFrame[(DataFrame['City']=='Chamonix')&(DataFrame['Sport']=='Skating')&(DataFrame['Discipline']=='Figure skating')]

# %%
DataFrame[(DataFrame['City']=='Chamonix')&(DataFrame['Sport']=='Skating')&(DataFrame['Discipline']=='Speed skating')]

# %%
DataFrame[(DataFrame['City']=='St. Moritz')&(DataFrame['Sport']=='Skating')&(DataFrame['Discipline']=='Figure skating')]

# %%
DataFrame[(DataFrame['City']=='St. Moritz')&(DataFrame['Sport']=='Skating')&(DataFrame['Discipline']=='Speed skating')]

# %%
DataFrame['Year'].unique()

# %%
DataFrame['City'].unique()

# %%
DataFrame['Discipline'].unique()

# %%
DataFrame.info() # xem thong tin dataframe

# %%
DataFrame.describe

# %%
DataFrame[(DataFrame['City']=='Lake Placid')&(DataFrame['Year']==1932)]

# %%
DataFrame[(DataFrame['City']=='Lake Placid')&(DataFrame['Year']==1980)]

# %%
DataFrame['Event'].unique()

# %% [markdown]
# nam 1928 , tp St. Moritz, huy chuong dong

# %%
DataFrame[(DataFrame['Year']==1928)&(DataFrame['City']=='St. Moritz')&(DataFrame['Medal']=='Bronze')].head(100)

# %%
DataFrame[(DataFrame['Year']==1928)&(DataFrame['City']=='St. Moritz')&(DataFrame['Medal']=='Silver')].head(100)

# %%
DataFrame[(DataFrame['Year']==1928)&(DataFrame['City']=='St. Moritz')&(DataFrame['Medal']=='Gold')].head(100)

# %%
DataFrame[(DataFrame['Year']==1948)&(DataFrame['City']=='St. Moritz')&(DataFrame['Medal']=='Bronze')].head(100)

# %%
DataFrame[(DataFrame['Year']==1948)&(DataFrame['City']=='St. Moritz')&(DataFrame['Medal']=='Silver')].head(100)

# %%
DataFrame[(DataFrame['Year']==1948)&(DataFrame['City']=='St. Moritz')&(DataFrame['Medal']=='Gold')].head(100)

# %%
DataFrame['City'].value_counts()

# %%
DataFrame[(DataFrame['Year']==1932)&(DataFrame['City']=='Lake Placid')&(DataFrame['Medal']=='Gold')].head(100)

# %%
DataFrame[(DataFrame['Year']==1932)&(DataFrame['City']=='Lake Placid')&(DataFrame['Medal']=='Silver')].head(100)

# %%
DataFrame[(DataFrame['Year']==1932)&(DataFrame['City']=='Lake Placid')&(DataFrame['Medal']=='Bronze')].head(100)

# %%
DataFrame.describe

# %%
DataFrame['Year'].plot.line()

# %%
group_df=DataFrame[['Medal','Event gender']]
group_df
# Out:
#        Medal Event gender
# 0     Silver            M
# 1       Gold            W
# 2       Gold            X
# 3     Bronze            M
# 4       Gold            M
# ...      ...          ...
# 2306  Silver            M
# 2307    Gold            W
# 2308  Silver            W
# 2309    Gold            M
# 2310  Silver            W
#
# [2311 rows x 2 columns]

# %%
group_df=group_df.groupby('Event gender').size()

# %%
group_df.plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff11e19f2e0>],
#       dtype=object)

# %%
group_df1=DataFrame[['City','Medal','Event']]
group_df1
# Out:
#           City   Medal            Event
# 0     Chamonix  Silver       individual
# 1     Chamonix    Gold       individual
# 2     Chamonix    Gold            pairs
# 3     Chamonix  Bronze         four-man
# 4     Chamonix    Gold       ice hockey
# ...        ...     ...              ...
# 2306     Turin  Silver        Half-pipe
# 2307     Turin    Gold        Half-pipe
# 2308     Turin  Silver        Half-pipe
# 2309     Turin    Gold  Snowboard Cross
# 2310     Turin  Silver  Snowboard Cross
#
# [2311 rows x 3 columns]

# %%
group_df1=group_df1.groupby('Event').size()

# %%
df= DataFrame[['Discipline','Medal']]
df
# Out:
#           Discipline   Medal
# 0     Figure skating  Silver
# 1     Figure skating    Gold
# 2     Figure skating    Gold
# 3          Bobsleigh  Bronze
# 4         Ice Hockey    Gold
# ...              ...     ...
# 2306       Snowboard  Silver
# 2307       Snowboard    Gold
# 2308       Snowboard  Silver
# 2309       Snowboard    Gold
# 2310       Snowboard  Silver
#
# [2311 rows x 2 columns]

# %%
df=df.groupby('Discipline').size()
df.plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff11e1420d0>],
#       dtype=object)

# %%
group_df1.plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff11dc45340>],
#       dtype=object)

# %% [markdown]
# array(['Chamonix', 'St. Moritz', 'Lake Placid', 'Garmisch-Partenkirchen',
#        'Oslo', "Cortina d'Ampezzo", 'Squaw Valley', 'Innsbruck',
#        'Grenoble', 'Sapporo', 'Sarajevo', 'Calgary', 'Albertville',
#        'Lillehammer', 'Nagano', 'Salt Lake City', 'Turin'

# %%
DataFrame[(DataFrame['City']=='Garmisch-Partenkirchen')].head(100)

# %%
DataFrame[(DataFrame['City']=='Oslo')].head(100)

# %%
df_city=DataFrame[['City','Medal']]
df_city

# %%
df_city=df_city.groupby('City').size()
df_city.plot.pie(subplots=True)

# %%
DataFrame[(DataFrame['NOC']=='GER')&(DataFrame['Medal']=='Gold')]
# Out:
#       Year                    City      Sport       Discipline  NOC  \
# 148   1936  Garmisch-Partenkirchen    Skating   Figure skating  GER
# 149   1936  Garmisch-Partenkirchen     Skiing    Alpine Skiing  GER
# 151   1936  Garmisch-Partenkirchen     Skiing    Alpine Skiing  GER
# 274   1952                    Oslo    Skating   Figure skating  GER
# 1337  1992             Albertville   Biathlon         Biathlon  GER
# 1339  1992             Albertville   Biathlon         Biathlon  GER
# 1342  1992             Albertville   Biathlon         Biathlon  GER
# 1347  1992             Albertville       Luge             Luge  GER
# 1349  1992             Albertville       Luge             Luge  GER
# 1351  1992             Albertville    Skating    Speed skating  GER
# 1353  1992             Albertville    Skating    Speed skating  GER
# 1355  1992             Albertville    Skating    Speed skating  GER
# 1358  1992             Albertville    Skating    Speed skating  GER
# ...

# %%
df_GER = DataFrame[['Sport','Medal']].count()
df_GER
# Out:
# Sport    2311
# Medal    2311
# dtype: int64

# %%
df_Nation= DataFrame[['NOC','Medal']]
df_Nation
df_Nation=df_Nation.groupby('NOC').size()
df_Nation.plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f15da84ba90>],
#       dtype=object)

# %%
DataFrame.groupby(['Sport'])['Medal'].count()
# Out:
# Sport
# Biathlon       162
# Bobsleigh      133
# Curling         21
# Ice Hockey      69
# Luge           108
# Skating        758
# Skiing        1060
# Name: Medal, dtype: int64

# %%
DataFrame[(DataFrame['Medal']=='Gold')&(DataFrame['NOC']=='GER')].min()
# Out:
# Year                     1936
# City              Albertville
# Sport                Biathlon
# Discipline      Alpine Skiing
# NOC                       GER
# Event                   1000m
# Event gender                M
# Medal                    Gold
# dtype: object

# %%
DataFrame[(DataFrame['Medal']=='Gold')&(DataFrame['NOC']=='GER')].max()
# Out:
# Year                     2006
# City                    Turin
# Sport                  Skiing
# Discipline      Speed skating
# NOC                       GER
# Event                 two-man
# Event gender                X
# Medal                    Gold
# dtype: object

# %%
DataFrame[(DataFrame['Medal']=='Silver')&(DataFrame['NOC']=='GER')]
# Out:
#       Year                    City      Sport       Discipline  NOC  \
# 147   1936  Garmisch-Partenkirchen    Skating   Figure skating  GER
# 150   1936  Garmisch-Partenkirchen     Skiing    Alpine Skiing  GER
# 152   1936  Garmisch-Partenkirchen     Skiing    Alpine Skiing  GER
# 275   1952                    Oslo     Skiing    Alpine Skiing  GER
# 278   1952                    Oslo     Skiing    Alpine Skiing  GER
# 1338  1992             Albertville   Biathlon         Biathlon  GER
# 1340  1992             Albertville   Biathlon         Biathlon  GER
# 1341  1992             Albertville   Biathlon         Biathlon  GER
# 1343  1992             Albertville   Biathlon         Biathlon  GER
# 1344  1992             Albertville  Bobsleigh        Bobsleigh  GER
# 1346  1992             Albertville  Bobsleigh        Bobsleigh  GER
# 1348  1992             Albertville       Luge             Luge  GER
# 1354  1992             Albertville    Skating    Speed skating  GER
# ...

# %%
DataFrame[(DataFrame['Medal']=='Silver')&(DataFrame['NOC']=='GER')].min()
# Out:
# Year                     1936
# City              Albertville
# Sport                Biathlon
# Discipline      Alpine Skiing
# NOC                       GER
# Event                   1000m
# Event gender                M
# Medal                  Silver
# dtype: object

# %%
DataFrame[(DataFrame['Medal']=='Silver')&(DataFrame['NOC']=='GER')].max()
# Out:
# Year                     2006
# City                    Turin
# Sport                  Skiing
# Discipline      Speed skating
# NOC                       GER
# Event                 two-man
# Event gender                X
# Medal                  Silver
# dtype: object

# %%
DataFrame[(DataFrame['Medal']=='Bronze')&(DataFrame['NOC']=='GER')]
# Out:
#       Year            City       Sport       Discipline  NOC  \
# 61    1928      St. Moritz   Bobsleigh        Bobsleigh  GER
# 103   1932     Lake Placid   Bobsleigh        Bobsleigh  GER
# 104   1932     Lake Placid  Ice Hockey       Ice Hockey  GER
# 276   1952            Oslo      Skiing    Alpine Skiing  GER
# 277   1952            Oslo      Skiing    Alpine Skiing  GER
# 1345  1992     Albertville   Bobsleigh        Bobsleigh  GER
# 1350  1992     Albertville        Luge             Luge  GER
# 1352  1992     Albertville     Skating    Speed skating  GER
# 1357  1992     Albertville     Skating    Speed skating  GER
# 1361  1992     Albertville     Skating    Speed skating  GER
# 1362  1992     Albertville      Skiing    Alpine Skiing  GER
# 1479  1994     Lillehammer    Biathlon         Biathlon  GER
# 1480  1994     Lillehammer    Biathlon         Biathlon  GER
# 1484  1994     Lillehammer   Bobsleigh        Bobsleigh  GER
# ...

# %%
DataFrame[(DataFrame['Medal']=='Bronze')&(DataFrame['NOC']=='GER')].min()
# Out:
# Year                     1928
# City              Albertville
# Sport                Biathlon
# Discipline      Alpine Skiing
# NOC                       GER
# Event                   1000m
# Event gender                M
# Medal                  Bronze
# dtype: object

# %%
DataFrame[(DataFrame['Medal']=='Bronze')&(DataFrame['NOC']=='GER')].max()
# Out:
# Year                     2006
# City                    Turin
# Sport                  Skiing
# Discipline      Speed skating
# NOC                       GER
# Event                 two-man
# Event gender                X
# Medal                  Bronze
# dtype: object

# %%
DataFrame['Year'].unique()
# Out:
# array([1924, 1928, 1932, 1936, 1948, 1952, 1956, 1960, 1964, 1968, 1972,
#        1976, 1980, 1984, 1988, 1992, 1994, 1998, 2002, 2006])

# %%
DataFrame['Sport'].unique()
# Out:
# array(['Skating', 'Bobsleigh', 'Ice Hockey', 'Biathlon', 'Skiing',
#        'Curling', 'Luge'], dtype=object)

# %% [markdown]
# so nam [1924, 1928, 1932, 1936, 1948, 1952, 1956, 1960, 1964, 1968, 1972,
#        1976, 1980, 1984, 1988, 1992, 1994, 1998, 2002, 2006])

# %%
DataFrame[(DataFrame['Year']==1928)&(DataFrame['NOC']=='GER')]
# Out:
#     Year        City      Sport Discipline  NOC     Event Event gender   Medal
# 61  1928  St. Moritz  Bobsleigh  Bobsleigh  GER  five-man            M  Bronze

# %%
DataFrame[(DataFrame['Year']==1932)&(DataFrame['NOC']=='GER')]
# Out:
#      Year         City       Sport  Discipline  NOC       Event Event gender  \
# 103  1932  Lake Placid   Bobsleigh   Bobsleigh  GER    four-man            M
# 104  1932  Lake Placid  Ice Hockey  Ice Hockey  GER  ice hockey            M
#
#       Medal
# 103  Bronze
# 104  Bronze

# %%
DataFrame[(DataFrame['Year']==1936)&(DataFrame['NOC']=='GER')]
# Out:
#      Year                    City    Sport      Discipline  NOC  \
# 147  1936  Garmisch-Partenkirchen  Skating  Figure skating  GER
# 148  1936  Garmisch-Partenkirchen  Skating  Figure skating  GER
# 149  1936  Garmisch-Partenkirchen   Skiing   Alpine Skiing  GER
# 150  1936  Garmisch-Partenkirchen   Skiing   Alpine Skiing  GER
# 151  1936  Garmisch-Partenkirchen   Skiing   Alpine Skiing  GER
# 152  1936  Garmisch-Partenkirchen   Skiing   Alpine Skiing  GER
#
#                Event Event gender   Medal
# 147       individual            M  Silver
# 148            pairs            X    Gold
# 149  alpine combined            M    Gold
# 150  alpine combined            M  Silver
# 151  alpine combined            W    Gold
# 152  alpine combined            W  Silver

# %%
DataFrame[(DataFrame['Year']==1936)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Skating')]
# Out:
#      Year                    City    Sport      Discipline  NOC       Event  \
# 147  1936  Garmisch-Partenkirchen  Skating  Figure skating  GER  individual
# 148  1936  Garmisch-Partenkirchen  Skating  Figure skating  GER       pairs
#
#     Event gender   Medal
# 147            M  Silver
# 148            X    Gold

# %%
DataFrame[(DataFrame['Year']==1936)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Skiing')]
# Out:
#      Year                    City   Sport     Discipline  NOC  \
# 149  1936  Garmisch-Partenkirchen  Skiing  Alpine Skiing  GER
# 150  1936  Garmisch-Partenkirchen  Skiing  Alpine Skiing  GER
# 151  1936  Garmisch-Partenkirchen  Skiing  Alpine Skiing  GER
# 152  1936  Garmisch-Partenkirchen  Skiing  Alpine Skiing  GER
#
#                Event Event gender   Medal
# 149  alpine combined            M    Gold
# 150  alpine combined            M  Silver
# 151  alpine combined            W    Gold
# 152  alpine combined            W  Silver

# %%
DataFrame[(DataFrame['Year']==1952)&(DataFrame['NOC']=='GER')]

# %%
DataFrame[(DataFrame['Year']==1952)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Skating')]
# Out:
#      Year  City    Sport      Discipline  NOC  Event Event gender Medal
# 274  1952  Oslo  Skating  Figure skating  GER  pairs            X  Gold

# %%
DataFrame[(DataFrame['Year']==1952)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Bobsleigh')]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, NOC, Event, Event gender, Medal]
# Index: []

# %%
DataFrame[(DataFrame['Year']==1952)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Ice Hockey')]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, NOC, Event, Event gender, Medal]
# Index: []

# %%
DataFrame[(DataFrame['Year']==1952)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Biathlon')]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, NOC, Event, Event gender, Medal]
# Index: []

# %%
DataFrame[(DataFrame['Year']==1952)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Skiing')]
# Out:
#      Year  City   Sport     Discipline  NOC         Event Event gender   Medal
# 275  1952  Oslo  Skiing  Alpine Skiing  GER      downhill            W  Silver
# 276  1952  Oslo  Skiing  Alpine Skiing  GER  giant slalom            W  Bronze
# 277  1952  Oslo  Skiing  Alpine Skiing  GER        slalom            W  Bronze
# 278  1952  Oslo  Skiing  Alpine Skiing  GER        slalom            W  Silver

# %%
DataFrame[(DataFrame['Year']==1952)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Curling')]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, NOC, Event, Event gender, Medal]
# Index: []

# %%
DataFrame[(DataFrame['Year']==1952)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Luge')]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, NOC, Event, Event gender, Medal]
# Index: []

# %%
DataFrame[(DataFrame['Year']== 1992)&(DataFrame['NOC']=='GER')]

# %%
DataFrame[(DataFrame['Year']==1992)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Skating')]

# %%
DataFrame[(DataFrame['Year']==1992)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Bobsleigh')]
# Out:
#       Year         City      Sport Discipline  NOC     Event Event gender  \
# 1344  1992  Albertville  Bobsleigh  Bobsleigh  GER  four-man            M
# 1345  1992  Albertville  Bobsleigh  Bobsleigh  GER   two-man            M
# 1346  1992  Albertville  Bobsleigh  Bobsleigh  GER   two-man            M
#
#        Medal
# 1344  Silver
# 1345  Bronze
# 1346  Silver

# %%
DataFrame[(DataFrame['Year']==1992)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Ice Hockey')]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, NOC, Event, Event gender, Medal]
# Index: []

# %%
DataFrame[(DataFrame['Year']==1992)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Biathlon')]
# Out:
#       Year         City     Sport Discipline  NOC          Event Event gender  \
# 1337  1992  Albertville  Biathlon   Biathlon  GER           10km            M
# 1338  1992  Albertville  Biathlon   Biathlon  GER           10km            M
# 1339  1992  Albertville  Biathlon   Biathlon  GER           15km            W
# 1340  1992  Albertville  Biathlon   Biathlon  GER           20km            M
# 1341  1992  Albertville  Biathlon   Biathlon  GER  3x7.5km relay            W
# 1342  1992  Albertville  Biathlon   Biathlon  GER  4x7.5km relay            M
# 1343  1992  Albertville  Biathlon   Biathlon  GER          7.5km            W
#
#        Medal
# 1337    Gold
# 1338  Silver
# 1339    Gold
# 1340  Silver
# 1341  Silver
# 1342    Gold
# 1343  Silver

# %%
DataFrame[(DataFrame['Year']==1992)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Skiing')]
# Out:
#       Year         City   Sport     Discipline  NOC    Event Event gender  \
# 1362  1992  Albertville  Skiing  Alpine Skiing  GER  super-G            W
#
#        Medal
# 1362  Bronze

# %%
DataFrame[(DataFrame['Year']==1992)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Curling')]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, NOC, Event, Event gender, Medal]
# Index: []

# %%
DataFrame[(DataFrame['Year']==1992)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Luge')]
# Out:
#       Year         City Sport Discipline  NOC    Event Event gender   Medal
# 1347  1992  Albertville  Luge       Luge  GER  doubles            X    Gold
# 1348  1992  Albertville  Luge       Luge  GER  doubles            X  Silver
# 1349  1992  Albertville  Luge       Luge  GER  singles            M    Gold
# 1350  1992  Albertville  Luge       Luge  GER  singles            W  Bronze

# %%
DataFrame[(DataFrame['Year']== 1994)&(DataFrame['NOC']=='GER')]

# %%
DataFrame[(DataFrame['Year']==1994)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Skating')]
# Out:
#       Year         City    Sport     Discipline  NOC  Event Event gender  \
# 1489  1994  Lillehammer  Skating  Speed skating  GER  1000m            W
# 1490  1994  Lillehammer  Skating  Speed skating  GER  1500m            W
# 1491  1994  Lillehammer  Skating  Speed skating  GER  3000m            W
# 1492  1994  Lillehammer  Skating  Speed skating  GER  5000m            W
# 1493  1994  Lillehammer  Skating  Speed skating  GER  5000m            W
# 1494  1994  Lillehammer  Skating  Speed skating  GER   500m            W
#
#        Medal
# 1489  Silver
# 1490  Bronze
# 1491  Bronze
# 1492    Gold
# 1493  Silver
# 1494  Bronze

# %%
DataFrame[(DataFrame['Year']==1994)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Bobsleigh')]

# %%
DataFrame[(DataFrame['Year']==1994)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Ice Hockey')]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, NOC, Event, Event gender, Medal]
# Index: []

# %%
DataFrame[(DataFrame['Year']==1994)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Biathlon')]
# Out:
#       Year         City     Sport Discipline  NOC          Event Event gender  \
# 1478  1994  Lillehammer  Biathlon   Biathlon  GER           10km            M
# 1479  1994  Lillehammer  Biathlon   Biathlon  GER           15km            W
# 1480  1994  Lillehammer  Biathlon   Biathlon  GER           20km            M
# 1481  1994  Lillehammer  Biathlon   Biathlon  GER           20km            M
# 1482  1994  Lillehammer  Biathlon   Biathlon  GER  4x7.5km relay            M
# 1483  1994  Lillehammer  Biathlon   Biathlon  GER  4x7.5km relay            W
#
#        Medal
# 1478  Silver
# 1479  Bronze
# 1480  Bronze
# 1481  Silver
# 1482    Gold
# 1483  Silver

# %%
DataFrame[(DataFrame['Year']==1994)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Skiing')]
# Out:
#       Year         City   Sport     Discipline  NOC                  Event  \
# 1495  1994  Lillehammer  Skiing  Alpine Skiing  GER               downhill
# 1496  1994  Lillehammer  Skiing  Alpine Skiing  GER           giant slalom
# 1497  1994  Lillehammer  Skiing  Alpine Skiing  GER           giant slalom
# 1498  1994  Lillehammer  Skiing  Alpine Skiing  GER                super-G
# 1499  1994  Lillehammer  Skiing    Ski Jumping  GER  K120 individual (90m)
# 1500  1994  Lillehammer  Skiing    Ski Jumping  GER        K120 team (90m)
# 1501  1994  Lillehammer  Skiing    Ski Jumping  GER   K90 individual (70m)
#
#      Event gender   Medal
# 1495            W    Gold
# 1496            M    Gold
# 1497            W  Silver
# 1498            M    Gold
# 1499            M    Gold
# 1500            M    Gold
# 1501            M  Bronze

# %%
DataFrame[(DataFrame['Year']==1994)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Curling')]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, NOC, Event, Event gender, Medal]
# Index: []

# %%
DataFrame[(DataFrame['Year']==1994)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Luge')]
# Out:
#       Year         City Sport Discipline  NOC    Event Event gender   Medal
# 1486  1994  Lillehammer  Luge       Luge  GER  doubles            X  Bronze
# 1487  1994  Lillehammer  Luge       Luge  GER  singles            M    Gold
# 1488  1994  Lillehammer  Luge       Luge  GER  singles            W  Silver

# %%
DataFrame[(DataFrame['Year']== 1998)&(DataFrame['NOC']=='GER')]

# %%
DataFrame[(DataFrame['Year']==1998)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Skating')]

# %%
DataFrame[(DataFrame['Year']==1998)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Bobsleigh')]

# %%
DataFrame[(DataFrame['Year']==1998)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Ice Hockey')]

# %%
DataFrame[(DataFrame['Year']==1998)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Biathlon')]

# %%
DataFrame[(DataFrame['Year']==1998)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Skiing')]

# %%
DataFrame[(DataFrame['Year']==1998)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Curling')]

# %%
DataFrame[(DataFrame['Year']==1998)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Luge')]

# %%
DataFrame[(DataFrame['Year']==2002)&(DataFrame['NOC']=='GER')]

# %%
DataFrame[(DataFrame['Year']==2002)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Skating')]

# %%
DataFrame[(DataFrame['Year']==2002)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Bobsleigh')]

# %%
DataFrame[(DataFrame['Year']==2002)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Ice Hockey')]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, NOC, Event, Event gender, Medal]
# Index: []

# %%
DataFrame[(DataFrame['Year']==2002)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Biathlon')]
# Out:
#       Year            City     Sport Discipline  NOC           Event  \
# 1903  2002  Salt Lake City  Biathlon   Biathlon  GER            10km
# 1904  2002  Salt Lake City  Biathlon   Biathlon  GER    10km pursuit
# 1905  2002  Salt Lake City  Biathlon   Biathlon  GER  12.5km pursuit
# 1906  2002  Salt Lake City  Biathlon   Biathlon  GER            15km
# 1907  2002  Salt Lake City  Biathlon   Biathlon  GER            20km
# 1908  2002  Salt Lake City  Biathlon   Biathlon  GER   4x7.5km relay
# 1909  2002  Salt Lake City  Biathlon   Biathlon  GER   4x7.5km relay
# 1910  2002  Salt Lake City  Biathlon   Biathlon  GER           7.5km
# 1911  2002  Salt Lake City  Biathlon   Biathlon  GER           7.5km
#
#      Event gender   Medal
# 1903            M  Silver
# 1904            W  Silver
# 1905            M  Bronze
# 1906            W    Gold
# 1907            M  Silver
# 1908            M  Silver
# 1909            W    Gold
# 1910            W    Gold
# 1911            W  Silver

# %%
DataFrame[(DataFrame['Year']==2002)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Skiing')]
# Out:
#       Year            City   Sport       Discipline  NOC  \
# 1929  2002  Salt Lake City  Skiing    Alpine Skiing  GER
# 1930  2002  Salt Lake City  Skiing  Cross Country S  GER
# 1931  2002  Salt Lake City  Skiing  Cross Country S  GER
# 1932  2002  Salt Lake City  Skiing  Cross Country S  GER
# 1933  2002  Salt Lake City  Skiing  Cross Country S  GER
# 1934  2002  Salt Lake City  Skiing  Cross Country S  GER
# 1935  2002  Salt Lake City  Skiing  Nordic Combined  GER
# 1936  2002  Salt Lake City  Skiing  Nordic Combined  GER
# 1937  2002  Salt Lake City  Skiing      Ski Jumping  GER
# 1938  2002  Salt Lake City  Skiing      Ski Jumping  GER
#
#                      Event Event gender   Medal
# 1929       alpine combined            W  Bronze
# 1930          4x10km relay            M  Bronze
# 1931           4x5km relay            W    Gold
# 1932           5km pursuit            W  Bronze
# 1933          Sprint 1.5km            M  Silver
# ...

# %%
DataFrame[(DataFrame['Year']==2002)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Curling')]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, NOC, Event, Event gender, Medal]
# Index: []

# %%
DataFrame[(DataFrame['Year']==2002)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Luge')]
# Out:
#       Year            City Sport Discipline  NOC    Event Event gender   Medal
# 1916  2002  Salt Lake City  Luge       Luge  GER  doubles            X    Gold
# 1917  2002  Salt Lake City  Luge       Luge  GER  singles            M  Silver
# 1918  2002  Salt Lake City  Luge       Luge  GER  singles            W  Bronze
# 1919  2002  Salt Lake City  Luge       Luge  GER  singles            W    Gold
# 1920  2002  Salt Lake City  Luge       Luge  GER  singles            W  Silver

# %%
DataFrame[(DataFrame['Year']==2006)&(DataFrame['NOC']=='GER')]

# %%
DataFrame[(DataFrame['Year']==2006)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Skating')]

# %%
DataFrame[(DataFrame['Year']==2006)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Bobsleigh')]

# %%
DataFrame[(DataFrame['Year']==2006)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Ice Hockey')]

# %%
DataFrame[(DataFrame['Year']==2006)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Biathlon')]

# %%
DataFrame[(DataFrame['Year']==2006)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Skiing')]

# %%
DataFrame[(DataFrame['Year']==2006)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Curling')]

# %%
DataFrame[(DataFrame['Year']==2006)&(DataFrame['NOC']=='GER')&(DataFrame['Sport']=='Luge')]

# %%
DataFrame[(DataFrame['Medal']=='Gold')&(DataFrame['NOC']=='GER')&(DataFrame['Event']=='singles')]
# Out:
#       Year            City Sport Discipline  NOC    Event Event gender Medal
# 1349  1992     Albertville  Luge       Luge  GER  singles            M  Gold
# 1487  1994     Lillehammer  Luge       Luge  GER  singles            M  Gold
# 1699  1998          Nagano  Luge       Luge  GER  singles            M  Gold
# 1700  1998          Nagano  Luge       Luge  GER  singles            W  Gold
# 1919  2002  Salt Lake City  Luge       Luge  GER  singles            W  Gold
# 2166  2006           Turin  Luge       Luge  GER  singles            W  Gold

# %% [markdown]
# array(['Skating', 'Bobsleigh', 'Ice Hockey', 'Biathlon', 'Skiing',
#        'Curling', 'Luge'], dtype=object)

# %%
ex3=DataFrame.groupby(['Medal'])['Medal'].count()
sum=DataFrame.groupby(['Medal'])['Medal'].count().sum()
mean=DataFrame.groupby(['Medal'])['Medal'].count().mean()
max=DataFrame.groupby(['Medal'])['Medal'].count().max()
min=DataFrame.groupby(['Medal'])['Medal'].count().min()
print("Gia tri nho nhat \n",min)
print("Gia tri lon nhat \n",max)
print("Gia tri trung binh \n",mean)
print("Gia tri tong \n",sum)
# Out:
# Gia tri nho nhat
#  764
# Gia tri lon nhat
#  774
# Gia tri trung binh
#  770.3333333333334
# Gia tri tong
#  2311
